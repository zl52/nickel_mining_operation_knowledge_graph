# %%
import pandas as pd
import math
from fuzzywuzzy import fuzz
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_rows = 999
pd.options.display.max_columns = 200

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

import glob

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # initialization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## global variable

# %%
num_years = 10
num_years_forcast = 10
time_step_per_year = 12

time_range = num_years * time_step_per_year
forcast_range = num_years_forcast * time_step_per_year

# %% [markdown]
# ## demand

# %%
# demand_f_df = pd.read_csv('total-nickel-demand-by-sector-and-scenario-2020-2040.csv', skiprows=3)
# del demand_f_df['Unnamed: 0']
# demand_f_df = demand_f_df.iloc[[0, 3, 4]]
# demand_f_df['year'] = [2020, 2030, 2040]
# demand_f_df

# %%
# demand_f_df2 = pd.DataFrame(columns=demand_f_df.columns)
# year = np.linspace(2020, 2040, 20 * time_step_per_year + 1)
# demand_f_df2['year'] = year
# demand_f_df2

# %%
# from scipy.interpolate import interp1d
# for c in ['Low-carbon power generation', 'EVs and storage', 'Hydrogen',
#          'Other sectors', 'Share of clean energy technologies']:
#     f = interp1d(demand_f_df['year'].tolist(), demand_f_df[c].tolist(), kind='quadratic')
#     year = np.linspace(2020, 2040, 20 * time_step_per_year + 1)
#     demand = f(year)
#     demand_f_df2[c] = demand
#     plt.plot(demand)
#     plt.show()

# %%
# demand_f_df2['overall_demand'] = demand_f_df2[['Low-carbon power generation', 'EVs and storage', 'Hydrogen', 'Other sectors']].sum(axis=1)
# demand_f_df2['overall_demand'].plot()

# %%
# demand_f_df2 = demand_f_df2.reset_index(drop=False)
# demand_f_df2

# %%
# demand_f  = (demand_f_df2[demand_f_df2['year']>2021]['overall_demand'] / 10).tolist()
# demand_f

# %%
hist_demand_df = pd.DataFrame([[2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013],
                          [240, 243, 235, 215, 203.7, 190.5, 186.3, 177.3]], index=['year', 'demand']).T
hist_demand_df = hist_demand_df.sort_values(by='year')
# hist_demand_df = hist_demand_df[hist_demand_df['year']<2020]
hist_demand_df['pct_change'] = hist_demand_df['demand'].pct_change()
hist_demand_df['year'] = hist_demand_df['year'].astype(int)
hist_demand_df
# Out:
#    year  demand  pct_change
# 7  2013   177.3         NaN
# 6  2014   186.3    0.050761
# 5  2015   190.5    0.022544
# 4  2016   203.7    0.069291
# 3  2017   215.0    0.055474
# 2  2018   235.0    0.093023
# 1  2019   243.0    0.034043
# 0  2020   240.0   -0.012346

# %%
hist_demand = hist_demand_df['demand'].tolist()
hist_year = (hist_demand_df['year']+0.5).tolist()
hist_demand
hist_year
# Out:
# [177.3, 186.3, 190.5, 203.7, 215.0, 235.0, 243.0, 240.0]
# [2013.5, 2014.5, 2015.5, 2016.5, 2017.5, 2018.5, 2019.5, 2020.5]

# %%
from scipy.interpolate import interp1d
f = interp1d(hist_year, hist_demand, kind='cubic')
hist_year2 = np.linspace(hist_year[0], hist_year[-1], 7 * time_step_per_year)
hist_demand2 = f(hist_year2)
hist_year2
hist_demand2
# Out:
# array([2013.5       , 2013.58433735, 2013.6686747 , 2013.75301205,
#        2013.8373494 , 2013.92168675, 2014.0060241 , 2014.09036145,
#        2014.1746988 , 2014.25903614, 2014.34337349, 2014.42771084,
#  390.44022565721815,
#  391.8501894988518,
#  393.2652450239343,
#  394.68541061963236,
#  396.11070473951276,
#  397.54114590378225,
#  398.9767526995279,
#  400.41754378095874,
#  401.8635378696482,
#  403.3147537547775,
#  404.77121029337934,
#  406.23292641058345,
#  407.69992109986225,
#  409.1722134232777,
#  410.6498225117289,
#  412.1327675652008,
#  413.6210678530137,
#  415.11474271407343,
#  416.6138115571228,
#  418.1182938609939,
#  419.62820917486107,
#  421.14357711849476,
#  422.6644173825168,
#  424.19074972865604,
#  425.72259399000524,
#  427.25997007127864,
#  428.8028979490709,
#  430.35139767211615,
#  431.9054893615491,
#  433.4651932111661,
#  435.03052948768766,
#  436.6015185310218,
#  438.17818075452834,
#  439.7605366452841,
#  441.34860676434926,
#  442.94241174703427,
#  444.5419723031682,
#  446.147309217368,
#  447.75844334930787,
#  449.3753956339912,
#  450.998187082022,
#  452.62683877987826,
#  454.2613718901856,
#  455.90180765199256,
#  457.5481673810464,
#  459.2004724700703,
#  460.85874438904085,
#  462.5230046854677,
#  464.193274984673,
#  465.86957699007274,
#  467.55193248345853,
#  469.24036332528067,
#  470.9348914549323,
#  472.63553889103457,
#  474.3423277317225,
#  476.05528015493223,
#  477.77441841868927,
#  479.4997648613976,
#  481.23134190213,
#  482.9691720409195,
#  484.7132778590513,
#  486.46368201935684,
#  488.2204072665076,
#  489.9834764273112,
#  491.7529124110078,
#  493.52873820956756,
#  495.31097689798975,
#  497.0996516346025,
#  498.89478566136336,
#  500.69640230416206,
#  502.5045249731227,
#  504.3191771629087,
#  506.1403824530277,
#  507.9681645081379,
#  509.80254707835564,
#  511.6435539995644,
#  513.4912091937238,
#  515.3455366691811,
#  517.2065605209826,
#  519.0743049311873,
#  520.9487941691806,
#  522.8300525919899,
#  524.7181046446012,
#  526.6129748602767,
#  528.5146878608731,
#  530.4232683571624,
#  532.3387411491523,
#  534.2611311264085,
#  536.1904632683786,
#  538.1267626447163,
#  540.0700544156072,
#  542.0203638320957,
#  543.9777162364131,
#  545.9421370623072,
#  547.9136518353722,
#  549.8922861733812,
#  551.8780657866182,
#  553.8710164782127,
#  555.871164144475,
#  557.8785347752322]

# %%
# growth_f = np.empty(shape=(num_years*time_step_per_year))
# growth_f[:] = np.NaN

# demand_f = trend_f = np.empty(shape=(num_years*time_step_per_year, num_years_forcast*time_step_per_year))
# demand_f[:] = trend_f[:] = np.NaN

# alpha_dtdf = (1 - np.exp(np.log10(0.5) / (3 * time_step_per_year)))
# alpha_dgdf = (1 - np.exp(np.log10(0.5) / (3 * time_step_per_year)))
# r_dfdt = np.log10(2) / (3/4)
 

# growth_f[0] = growth_rate
# trend_f[0][0] = hist_demand2[-1]
# for tf in range(forcast_range):
#     trend_f[0, tf] = trend_f[0, 0] * (1 + growth_f[0])**(tf-0)

# %% [markdown]
# ## supply

# %%
df = pd.read_excel('nickel_mine_final.xlsx')
df = df.applymap(lambda x: str(x).replace('*', '').replace('nan', '')).apply(pd.to_numeric, errors='ignore')

# %%
from fitter import get_common_distributions, Fitter, get_distributions
from scipy.stats import chi2
from scipy.stats import uniform

dev_lead_time = [2,3,2,4,3,3,3,3,8,6,8,3,10,7,6,10,10,6,7,11,16,11,16,16,9,18,18,18,24,27]

# f1 = Fitter(dev_lead_time,
#             distributions=get_common_distributions())
# f1.fit()
# f1.summary()

f1 = Fitter(dev_lead_time,
            distributions=['chi2'])
f1.fit()
f1.summary()

chi2.rvs(size=100, **f1.get_best()['chi2']).astype(int)
# Out:
#       sumsquare_error         aic        bic  kl_div
# chi2         1.386311  753.725861 -82.032935     inf
# array([ 5,  4,  3,  3,  2, 11,  3,  2, 20, 20,  3,  2,  6,  2,  7,  2, 51,
#         2,  9, 12,  2,  8,  4, 13,  7, 14,  5,  3, 17,  4,  4,  6,  5,  3,
#         3, 12,  2,  6,  3,  3,  3,  6,  2,  3,  3,  7,  5,  7,  3,  4,  5,
#         8,  6, 15, 10,  4,  2, 15, 14,  2, 17, 13,  8, 10,  5,  2,  8,  7,
#         6,  4,  8, 11,  4,  3,  5,  2,  2,  4,  9,  5, 10,  2,  7,  6,  4,
#         5,  7,  5,  3,  9,  7,  5,  6,  5,  5, 12, 14, 14,  5, 35])

# %%
# 0 9 4
dev_lead_time = [2,1,3,2,5,5,5,6,2,4,3,8,1,4,6,2,4,9,8,5,1,6,1,2,9,1,5,5,0,0]


# f2 = Fitter(dev_lead_time,
#             distributions=get_common_distributions())
# f2.fit()
# f2.summary()

f2 = Fitter(dev_lead_time,
            distributions=['uniform'])
f2.fit()
f2.summary()

uniform.rvs(size=100, **f2.get_best()['uniform']).astype(int)
# Out:
#          sumsquare_error         aic        bic  kl_div
# uniform        15.226337  443.444915 -13.542727     inf
# array([2, 3, 5, 8, 1, 0, 1, 4, 7, 4, 0, 7, 5, 8, 7, 6, 8, 1, 3, 7, 4, 8,
#        8, 4, 5, 3, 6, 3, 0, 7, 6, 5, 8, 1, 2, 3, 7, 8, 1, 5, 5, 7, 0, 4,
#        7, 6, 0, 3, 8, 0, 3, 6, 6, 0, 6, 6, 0, 7, 7, 0, 3, 5, 2, 1, 4, 3,
#        2, 6, 6, 6, 2, 7, 1, 5, 2, 6, 8, 1, 2, 2, 4, 0, 0, 3, 1, 8, 5, 3,
#        5, 7, 7, 3, 1, 3, 7, 2, 8, 8, 7, 2])

# %%
stage_dic = {'Grassroots':'Early-stage exploration',
'Exploration':'Early-stage exploration',
'Target Outline':'Early-stage exploration',

'Advanced Exploration':'Late-stage exploration',
'Prefeas/Scoping':'Late-stage exploration',
 
'Feasibility Started':'Feasibility-stage',
'Feasibility':'Feasibility-stage',
 
'Feasibility Complete':'Development-stage',
'Reserves Development':'Development-stage',

'Satellite':'Construction-stage',
'Construction Planned':'Construction-stage',
'Construction Started':'Construction-stage',
 
'Commissioning':'Construction-stage',
'Preproduction':'Construction-stage',

'Operating':'Operating-stage',
 
'Limited Production':'Operating-stage',
'Expansion':'Operating-stage',
'Closed':'Closed-stage'}

df['current_stage'] = df['dev_stage'].map(stage_dic)

# %%
df.groupby('current_stage')['cash_cost (nickel USD/t)'].mean()
# Out:
# current_stage
# Closed-stage               12409.232157
# Construction-stage          9664.175714
# Development-stage          11183.343370
# Early-stage exploration    10121.181587
# Feasibility-stage          12639.803607
# Late-stage exploration     12950.766067
# Operating-stage             9372.785808
# Name: cash_cost (nickel USD/t), dtype: float64

# %%
df = df[df['resource_metal (mt)'].notnull()]

df.loc[(df['production_PROD_Ni_tpa'].isnull())&(df['current_stage'].isin(['Operating-stage'])), 'current_stage']='Development-stage' 
df.loc[(df['reserve_metal (mt)'].isnull())&(df['current_stage'].isin(['Development-stage', 'Operating-stage'])), 'current_stage']='Feasibility-stage'

df.loc[(df['production_PROD_Ni_tpa'].notnull())&(df['current_stage'].isin(['Early-stage exploration', 'Late-stage exploration', 'Feasibility-stage', 'Development-stage'])), 'current_stage']='Operating-stage' 
df.loc[(df['reserve_metal (mt)'].notnull())&(df['current_stage'].isin(['Early-stage exploration', 'Late-stage exploration', 'Feasibility-stage'])), 'current_stage']='Development-stage'

df = df[df['current_stage']!='Early-stage exploration']
# df = df[df['dev_stage']!='Closed-stage']
# df = df[df['actv_status']!='Inactive']

# %%
from scipy.stats import chi2

df2 = df.copy()

exp_stage_index = df2['current_stage']=='Late-stage exploration'
df2.loc[exp_stage_index, 'late_exp_stage_lead_time'] = np.round(np.random.uniform(0, 3, size=sum(exp_stage_index)) * time_step_per_year, 0)
df2.loc[exp_stage_index, 'late_exp_stage_left_time'] = np.round(df2.loc[exp_stage_index, 'late_exp_stage_lead_time'] * np.random.rand(sum(exp_stage_index)), 0)

fea_stage_index = df2['current_stage'].isin(['Late-stage exploration', 'Feasibility-stage'])
df2.loc[fea_stage_index, 'fea_stage_lead_time'] = np.round(chi2.rvs(size=sum(fea_stage_index), **f1.get_best()['chi2']) * time_step_per_year, 0)
df2.loc[fea_stage_index, 'fea_stage_left_time'] = np.round(df2.loc[fea_stage_index, 'fea_stage_lead_time'] * np.random.rand(sum(fea_stage_index)), 0)

dev_stage_index = df2['current_stage'].isin(['Late-stage exploration', 'Feasibility-stage', 'Development-stage', 'Construction-stage'])
df2.loc[dev_stage_index, 'dev_stage_lead_time'] = np.round(uniform.rvs(size=sum(dev_stage_index), **f2.get_best()['uniform']) * time_step_per_year, 0)
df2.loc[dev_stage_index, 'dev_stage_left_time'] = np.round(df2.loc[dev_stage_index, 'dev_stage_lead_time'] * np.random.rand(sum(dev_stage_index)), 0)

df2['overall_left_time'] = df2['late_exp_stage_left_time'].fillna(0) + df2['fea_stage_left_time'].fillna(0) + df2['dev_stage_left_time'].fillna(0)
df2['overall_lead_time'] = df2['late_exp_stage_lead_time'].fillna(0) + df2['fea_stage_lead_time'].fillna(0) + df2['dev_stage_lead_time'].fillna(0)

# %%
supply_f = np.empty(shape=(num_years * time_step_per_year, num_years_forcast * time_step_per_year))
supply_f[:] = np.NaN
hist_supply = []

# %% [markdown]
# ## price

# %%
price_df = pd.read_excel('data/SPGlobal_PriceChart-Nickel(Chart)_12-May-2022.xls', sheet_name=1, skiprows=8)
price_df['Year-Month'] = price_df['Date'].map(lambda x: str(x)[:7])
price_df['Month'] = price_df['Date'].map(lambda x: str(x)[5:7])
price_df = price_df.sort_values(by='Year-Month')
price_df = price_df[price_df['Year-Month']<'2020-01']
# price_df = price_df[price_df['Month'].isin(['01', '04', '07', '10'])]
price_df['LME-Nickel Cash ($/tonne)'].plot()
hist_price = price_df['LME-Nickel Cash ($/tonne)'].tolist()
# Out:
# <AxesSubplot:>

# %%
price_ma = np.empty(shape=(num_years*time_step_per_year))
price_ma[:] = np.NaN

price_range = np.empty(shape=(num_years * time_step_per_year, num_years_forcast * time_step_per_year))
price_f = np.empty(shape=(num_years * time_step_per_year, num_years_forcast * time_step_per_year))
price_dsm = np.empty(shape=(num_years * time_step_per_year, num_years_forcast * time_step_per_year))
price_range[:] = np.NaN
price_dsm[:] = np.NaN
price_f[:] = np.NaN

# %% [markdown]
# ## run simulation

# %%
prob_produce = 0.1
t_DD = 1 # years
t_DD *= time_step_per_year # intervals
t_FD = 1
t_FD *= time_step_per_year # intervals

# %%
demand_f = np.array([demand_f[i:i+forcast_range] for i in range(time_range)])
demand_f.shape
# Out:
# (120, 120)

# %%
def supply_simulation_one_step(df, t, tf):
    
    # have stepped into operating stage
    df_t.loc[df_t['overall_left_time']<=0, 'current_stage'] = 'Operating-stage'
    op_stage_index = df_t['current_stage'].isin(['Operating-stage'])
    non_op_stage_index = df_t['current_stage'].isin(['Feasibility-stage', 'Late-stage exploration', 'Construction-stage', 'Development-stage']) 

    # step into new stage now
    df_t.loc[non_op_stage_index, 'overall_left_time'] -= 1

    exp_stage_index = df_t['current_stage']=='Late-stage exploration'
    df_t.loc[exp_stage_index, 'late_exp_stage_left_time'] -=1
    exp_stage_finished_index = df_t['late_exp_stage_left_time']<=0 # enter new stage
    df_t.loc[exp_stage_finished_index, 'late_exp_stage_left_time'] = np.nan
    df_t.loc[exp_stage_finished_index, 'current_stage'] = 'Feasibility-stage'

    fea_stage_index = df_t['current_stage'].isin(['Feasibility-stage'])
    df_t.loc[fea_stage_index, 'fea_stage_left_time'] -=1
    fea_finished_index = df_t['fea_stage_left_time']<=0 # reserve delcaration and enter new stage
    df_t.loc[fea_finished_index, 'fea_stage_left_time'] = np.nan
    df_t.loc[fea_finished_index, 'current_stage'] = 'Development-stage'

    dev_stage_index = df_t['current_stage'].isin(['Development-stage', 'Construction-stage'])
    df_t.loc[dev_stage_index, 'dev_stage_left_time'] -=1
    dev_finished_index = df_t['dev_stage_left_time']<=0 # enter new stage
    df_t.loc[dev_finished_index, 'dev_stage_left_time'] = np.nan
    df_t.loc[dev_finished_index, 'current_stage'] = 'Operating-stage'

    op_stage_index = df_t['current_stage'].isin(['Operating-stage'])
    non_op_stage_index = df_t['current_stage'].isin(['Feasibility-stage', 'Late-stage exploration', 'Construction-stage', 'Development-stage'])

    # probability of producing
    df_t['dev_complete_ratio'] = (1 - df_t['overall_left_time'] / df_t['overall_lead_time']).fillna(1)
    df_t.loc[op_stage_index, 'prob_produce'] = 1
    df_t.loc[non_op_stage_index, 'prob_produce'] = df_t.loc[non_op_stage_index].apply(
                                 lambda x: prob_produce + (1 - prob_produce) * x['dev_complete_ratio'] if 
                                           tf / x['overall_left_time'] + x['dev_complete_ratio'] >= 1 else 0, axis=1)

    # reserve delcaration 
    resv_delcare_index = op_stage_index & (df_t['reserve_metal (mt)'].isnull())
    modification_rate = np.random.normal(loc=0.4, scale=0.1, size=sum(resv_delcare_index))
    df_t.loc[resv_delcare_index, 'reserve_metal (mt)'] = df_t.loc[resv_delcare_index, 'resource_metal (mt)'] * modification_rate

    # production capacity declaration
    a = 0.01692391768667905 # Laterite
    b = 0.7078073223232975
    df_t['production_capacity_L'] = df_t['reserve_metal (mt)'].map(lambda x: func(x,a,b)) * 350
    a = 7.500699276531266e-06 # Magmatic Sulphide
    b = 1.1996374863757813
    df_t['production_capacity_S'] = df_t['reserve_metal (mt)'].map(lambda x: func(x,a,b)) * 350
    sulphide_index = op_stage_index * (df_t['deposit_type']=='Magmatic Sulphide') & (df_t['production_capacity'].isnull())
    df_t.loc[sulphide_index, 'production_capacity'] = df_t.loc[sulphide_index, 'production_capacity_S']
    laterite_index = op_stage_index * (df_t['deposit_type']=='Laterite') & (df_t['production_capacity'].isnull())
    df_t.loc[laterite_index, 'production_capacity'] = df_t.loc[laterite_index, 'production_capacity_L']
    other_deposit_index = op_stage_index * (-df_t['deposit_type'].isin(['Magmatic Sulphide', 'Laterite'])) & df_t['production_capacity'].isnull()
    df_t.loc[other_deposit_index, 'production_capacity'] = (df_t.loc[other_deposit_index, 'production_capacity_S'] + df_t.loc[other_deposit_index, 'production_capacity_L']) / 2
    df_t.loc[df['production_capacity']<100, 'current_stage'] = 'Closed-stage' # too low
    df_t.loc[df['production_capacity']<100, 'actv_status'] = 'Inactive' # too low

    # production declaration
    production_declare_index = op_stage_index & (df_t['production_PROD_Ni_tpa'].isnull())
    df_t.loc[production_declare_index, 'production_PROD_Ni_tpa'] = df_t.loc[production_declare_index, 'production_capacity']

    # production
    df_t.loc[op_stage_index, 'production_PROD_Ni_tpa'] = df_t.loc[op_stage_index].apply(lambda x: min(x['production_PROD_Ni_tpa'], x['production_capacity']), axis=1) # can't exceed production capacity
    df_t.loc[op_stage_index, 'production_PROD_Ni_tpa'] = df_t.loc[op_stage_index].apply(lambda x: min(x['production_PROD_Ni_tpa'], x['recovery_Ni_perc'] * x['reserve_metal (mt)']), axis=1) # can't exceed remaining reserve
    df_t.loc[op_stage_index, 'production_ROM_Ni_tpa'] = df_t.loc[op_stage_index, 'production_PROD_Ni_tpa'] / df_t.loc[op_stage_index, 'recovery_Ni_perc'] # calculate raw ore containing nickel
    df_t.loc[op_stage_index, 'reserve_metal (mt)'] -= df_t.loc[op_stage_index, 'production_ROM_Ni_tpa'] # reserve decrease

    # if deplete
    resv_dep_index = op_stage_index & (df_t['reserve_metal (mt)']<=0)
    df_t.loc[resv_dep_index, 'reserve_metal (mt)'] = 0
    df_t.loc[resv_dep_index, 'production_PROD_Ni_tpa'] = df_t.loc[resv_dep_index, 'production_PROD_Ni_tpa'] = 0
    df_t.loc[resv_dep_index, 'current_stage'] = 'Closed-stage'
    df_t.loc[resv_dep_index, 'actv_status'] = 'Inactive'

    op_stage_index = df_t['current_stage'].isin(['Operating-stage'])
    supply = (df_t.loc[op_stage_index, 'production_PROD_Ni_tpa'] * df_t.loc[op_stage_index, 'prob_produce']).sum() /10000
    
    return df_t, supply

# %%
base_response = 5 # smaller the smaller ds effect
half_life_price_infl = 0.5 # larger the smaller ds effect
half_life_price_ma = 3
# half_life_price_conv = 5 # larger the smaller ma/p gap effect
half_life_price_ma *= time_step_per_year
# half_life_price_conv *= time_step_per_year
half_life_price_infl *= time_step_per_year

a_ppf = 1 - np.exp(np.log(0.5) / (half_life_price_ma * time_step_per_year))
# r_pfpmaf = -np.log(2) / half_life_price_conv
r_pfr = -np.log(2) / half_life_price_infl

# %%
df_t = df2.copy()
def func(x,a,b):
      return a*np.power(x, b)
    
for t in range(time_range):
    # price
    # calculate moving average price
    print('+++'*50, '\n', 2020+t//time_step_per_year,'%d/%d'%(t%time_step_per_year, time_step_per_year))
    price_ma[t] = sum(np.array([(1 - a_ppf)**i for i in range(len(hist_price), 0, -1)]) * np.array(hist_price))
    price_ma[t] /= sum(np.array([(1 - a_ppf)**i for i in range(len(hist_price), 0, -1)]))

    # ------------------------------------------------------------------------------------------------------------------------------------
    # ------------------------------------------------------------------------------------------------------------------------------------
    # ------------------------------------------------------------------------------------------------------------------------------------
    # forecast
    for tf in range(forcast_range):
        # ------------------------------------------------------------------------------------------------------------------------------------
        # demand
#         trend_f[t, t] = (1 - alpha_dtdf) * trend_f[t-1, t] + alpha_dtdf * hist_demand2[-1] #Dt -> hist_demand2[-1]
#         growth_f[t] = (1 - alpha_dgdf) * np.log(1 + growth_f[t-1]) + alpha_dgdf * np.log(trend_f[t, t] / trend_f[t-1, t-1])
#         growth_f[t] = np.exp(growth_f[t]) - 1
#         trend_f[t, tf] = trend_f[t, t] * (1 + growth_f[t])**(tf - t)
#         demand_f[t, tf] = + np.exp(-r_dfdt * (tf - t)) * (hist_demand2[-1] - trend_f[t, tf]) #Dt -> hist_demand2[-1]
        
        # ------------------------------------------------------------------------------------------------------------------------------------
        # supply forecast
        df_t, supply = supply_simulation_one_step(df_t, t, tf) # simulation without decision-making
#         if supply / demand_f[t, tf] > 1.1:
#             supply = demand_f[t, tf] * 1.1
        supply_f[t, tf] = supply
        if tf==0: # t, t+1 simulation without decision-making is stored
            df_t_copy = df_t.copy()
        
        # when forecasting, developing deposits have probability of being abandoned
        df_t['prob_abort_now'] = np.exp(np.log(1 + (1- df_t['prob_produce']) * (df_t['overall_left_time'] / df_t['overall_lead_time'])) / df_t['overall_left_time']) - 1 
        prob_abort_index = (df_t['prob_abort_now'].notnull()) & (df_t['current_stage']!='Operating-stage')
        df_t.loc[prob_abort_index, 'current_stage'] = df_t.loc[prob_abort_index].apply(
                 lambda x: x['current_stage'] if np.random.binomial(1, x['prob_abort_now'], 1)[0]==0 else 'Closed-stage', axis=1)

        # ------------------------------------------------------------------------------------------------------------------------------------
        # price forecast
        price_range[t, tf] = base_response / time_step_per_year * np.exp(-r_pfr * tf / time_step_per_year)
#         if tf==0:
#             price_dsm[t, tf] = np.log(price_ma[t]) + np.exp(-r_pfpmaf * 1/time_step_per_year) * (np.log(hist_price[-1]) - np.log(price_ma[t]))
#         else:
#             price_dsm[t, tf] = np.log(price_ma[t]) + np.exp(-r_pfpmaf * 1/time_step_per_year) * (np.log(price_f[t, tf-1]) - np.log(price_ma[t]))
#         price_dsm[t, tf] = np.exp(price_dsm[t, tf])
#         price_f[t, tf] = np.exp(np.log(price_dsm[t, tf]) + price_range[t, tf] * np.log(demand_f[t, tf] / supply_f[t, tf]))
        
        price_f[t, tf] = np.exp(np.log(price_ma[t]) + price_range[t, tf] * np.log(demand_f[t, tf] / supply_f[t, tf]))
        if tf%time_step_per_year==0:
#             print('forecast time: +%d Year time_inf_range:%.2f pma:%.2f d:%.2f s:%.2f d/s:%.2f p_dsm:%.2f price:%.2f, %.2f'%(
#                   tf/time_step_per_year, price_range[t, tf], price_ma[t], demand_f[t, tf], supply_f[t, tf], demand_f[t, tf] / supply_f[t, tf], price_dsm[t, tf], price_f[t, tf], price_f[t, t])) 
            print('forecast time: +%d Year time_inf_range:%.2f pma:%.2f d:%.2f s:%.2f d/s:%.2f price:%.2f'%(
                  tf/time_step_per_year+1, price_range[t, tf], price_ma[t], demand_f[t, tf], supply_f[t, tf], demand_f[t, tf] / supply_f[t, tf], price_f[t, tf]))
#             print(np.log(price_ma[t]), price_range[t, tf] * np.log(demand_f[t, tf] / supply_f[t, tf]))
    # ------------------------------------------------------------------------------------------------------------------------------------
    # ------------------------------------------------------------------------------------------------------------------------------------
    # ------------------------------------------------------------------------------------------------------------------------------------
    # supply 

    # current step's (+1) simulation without decision-making
    df_t = df_t_copy
    # every year developer has a chance to halt or restore (decision-making)
#     if t%time_step_per_year==0:
    if True:
        print('decision-making:')
        # halt developing
        df_t[['if_halt_developing', 'if_shutdown', 'if_restore']] = np.nan
        index = (df_t['dev_stage_left_time']>=2)
        df_t.loc[index, 'if_halt_developing'] = df_t.loc[index].apply(lambda x: 1 if x['cash_cost (nickel USD/t)'] * (1+0.05)**((t+int(x['dev_stage_left_time']))/time_step_per_year) > np.mean(
            price_f[t, int(x['dev_stage_left_time']):int(x['dev_stage_left_time'] + t_DD)]) else 0, axis=1)
        print(df_t['if_halt_developing'].sum(), 'halt developing')
        # shutdown
        index = (df_t['current_stage']=='Operating-stage') & ((df_t['production_PROD_Ni_tpa'].notnull()))
        df_t.loc[index, 'if_shutdown'] = df_t.loc[index].apply(lambda x: 1 if x['cash_cost (nickel USD/t)'] * (1+0.05)**(t/time_step_per_year) > np.mean(
            price_f[t, 0:t_DD]) else 0, axis=1)
        print(df_t['if_shutdown'].sum(), 'shutdown')
        
        if_abandon_index = (df_t['if_halt_developing']==1) | (df_t['if_shutdown']==1)
        df_t.loc[if_abandon_index, 'current_stage'] = 'halt'
        df_t.loc[if_abandon_index, 'dev_stage_left_time'] = df_t.loc[if_abandon_index, 'dev_stage_left_time'].fillna(0) + 2

        df_t.loc[df_t['current_stage']=='halt', 'if_restore'] = df_t.loc[df_t['current_stage']=='halt'].apply(lambda x: 1 if x['cash_cost (nickel USD/t)'] * (1+0.05)**((t+int(x['dev_stage_left_time']))/time_step_per_year) <= np.mean(
            price_f[t, int(x['dev_stage_left_time']):int(x['dev_stage_left_time'] + t_DD)]) else 0, axis=1)
        df_t.loc[df_t['if_restore']==1, 'current_stage'] = 'development-stage'
        print(df_t['if_restore'].sum(), 'restore')
        # base on current step's (+1) simulation with decision-making as the inital status of next step's simulation

#     capacity    
    hist_price = np.append(hist_price, price_f[t, t])
    hist_demand2 = np.append(hist_demand2, demand_f[t, t])

    op_stage_index = df_t['current_stage']=='Operating-stage'
    supply = (df_t.loc[op_stage_index, 'production_PROD_Ni_tpa']).sum() /10000
    print('supply', supply, 'demand', demand_f[t, t], 'price', price_f[t, t])
    hist_supply = hist_supply + [supply]
    if t==0:
        break
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  2020 0/12
# forecast time: +1 Year time_inf_range:0.42 pma:15571.05 d:241.99 s:284.17 d/s:0.85 price:14562.72
# forecast time: +2 Year time_inf_range:0.47 pma:15571.05 d:246.13 s:353.03 d/s:0.70 price:13154.06
# forecast time: +3 Year time_inf_range:0.52 pma:15571.05 d:257.01 s:433.77 d/s:0.59 price:11830.18
# forecast time: +4 Year time_inf_range:0.59 pma:15571.05 d:268.37 s:504.44 d/s:0.53 price:10735.45
# forecast time: +5 Year time_inf_range:0.66 pma:15571.05 d:280.24 s:566.14 d/s:0.50 price:9779.70
# forecast time: +6 Year time_inf_range:0.74 pma:15571.05 d:292.63 s:675.06 d/s:0.43 price:8371.48
# forecast time: +7 Year time_inf_range:0.83 pma:15571.05 d:305.56 s:714.05 d/s:0.43 price:7675.84
# forecast time: +8 Year time_inf_range:0.94 pma:15571.05 d:319.07 s:761.07 d/s:0.42 price:6905.15
# forecast time: +9 Year time_inf_range:1.05 pma:15571.05 d:333.17 s:789.83 d/s:0.42 price:6291.27
# forecast time: +10 Year time_inf_range:1.18 pma:15571.05 d:347.90 s:798.01 d/s:0.44 price:5853.41
# decision-making:
# 141.0 halt developing
# 17.0 shutdown
# 0.0 restore
# supply 251.7304161522823 demand 241.99110508770679 price 14562.71816025823

# %%
pd.DataFrame(price_f)
# Out:
#              0             1             2            3             4    \
# 0    14562.71816  14480.261447  14460.236059  14329.12534  14299.352614
# 1            NaN           NaN           NaN          NaN           NaN
# 2            NaN           NaN           NaN          NaN           NaN
# 3            NaN           NaN           NaN          NaN           NaN
# 4            NaN           NaN           NaN          NaN           NaN
# 5            NaN           NaN           NaN          NaN           NaN
# 6            NaN           NaN           NaN          NaN           NaN
# 7            NaN           NaN           NaN          NaN           NaN
# 8            NaN           NaN           NaN          NaN           NaN
# 9            NaN           NaN           NaN          NaN           NaN
# 10           NaN           NaN           NaN          NaN           NaN
# 11           NaN           NaN           NaN          NaN           NaN
# 12           NaN           NaN           NaN          NaN           NaN
# 104         NaN        NaN          NaN          NaN         NaN
# 105         NaN        NaN          NaN          NaN         NaN
# 106         NaN        NaN          NaN          NaN         NaN
# 107         NaN        NaN          NaN          NaN         NaN
# 108         NaN        NaN          NaN          NaN         NaN
# 109         NaN        NaN          NaN          NaN         NaN
# 110         NaN        NaN          NaN          NaN         NaN
# 111         NaN        NaN          NaN          NaN         NaN
# 112         NaN        NaN          NaN          NaN         NaN
# 113         NaN        NaN          NaN          NaN         NaN
# 114         NaN        NaN          NaN          NaN         NaN
# 115         NaN        NaN          NaN          NaN         NaN
# 116         NaN        NaN          NaN          NaN         NaN
# 117         NaN        NaN          NaN          NaN         NaN
# 118         NaN        NaN          NaN          NaN         NaN
# 119         NaN        NaN          NaN          NaN         NaN

# %%
df[df_t['if_shutdown']==1]
# Out:
#       prop_id          prop_name  \
# 67    27713.0           Savannah
# 68    27634.0                SNL
# 70    27742.0               Goro
# 73    82849.0           Mt Keith
# 74    26560.0  Manitoba Division
# 75    28019.0     Loma de Niquel
# 107       NaN           Northmet
# 143   57897.0   Mt Thirsty South
# 266   31028.0            Highway
# 301   29592.0             Niwest
# 341   27077.0        Nickel West
# 346   28247.0     Honeymoon Well
# 394   27361.0         Turfspruit
# 455   30235.0           Tiebaghi
# 914   58282.0         Hongqiling
# 1030  27659.0               Hart
# 1157  36105.0     Yuzhuralnickel
#
#                                           also_known_as  \
# 67    Copernicus, Dave Hill, E80/4834, E80/4880, E80...
# 68
# 70                                                  VNC
# 73                             Mount Keith, Nickel West
# 74    Birchtree, D-1, Footwall Deep, Moak, Pipe 1, P...
# 75                                  LDH, Loma de Hierro
# 107
# 143
# 266   Comet Vale, Highway Extended, Kalgoorlie Nicke...
# 301   Camelback, Duck Hill, E39/1784, E39/1794, E39/...
# 341   Cliffs, Kalgoorlie Smelter, Kambalda Concentra...
# 346   Capital, Corella, Hannibals, Harakka, Harrier,...
# 394                                            Platreef
# 455                                            Tiebargi
# 914
# 1030                                 McWatters, Tontine
# 1157    Buruktalsk, Sakhara, Sakharinsk, Southern Urals
#
#                                              owner_name owner_country  \
# 67                          Panoramic Resources Limited     Australia
# 68                                          ERAMET S.A.        France
# 70                                              Vale SA        France
# 73                                            BHP Group     Australia
# 74                                            Vale S.A.        Brazil
# 75                   República Bolivariana de Venezuela     Venezuela
# 107
# 143
# 266                             Ardea Resources Limited     Australia
# 301                               GME Resources Limited     Australia
# 341                                           BHP Group     Australia
# 346   Public Joint Stock Company Mining and Metallur...     Australia
# 394   Ivanhoe Mines Ltd (64%); black empowerment org...    Luxembourg
# 455                                         ERAMET S.A.        France
# 914
# 1030               Jilin Jien Nickel Industry Co., Ltd.         China
# 1157                                         Mechel PAO        Russia
#
#        country_name        actv_status  dev_stage   mine_type1  longitude  \
# 67        Australia             Active  Operating  Underground  128.02609
# 68    New Caledonia             Active  Operating     Open Pit  165.68456
# 70    New Caledonia             Active  Operating     Open Pit  166.96852
# 73        Australia             Active  Operating     Open Pit  120.59420
# 74           Canada             Active  Operating  Underground  -97.88904
# 914             Nickel                               Nickel,Copper,Cobalt
# 1030            Nickel                               Nickel,Copper,Cobalt
# 1157            Nickel                                             Nickel
#
#                       deposit_type  \
# 67               Magmatic Sulphide
# 68                        Laterite
# 70                        Laterite
# 73               Magmatic Sulphide
# 74               Magmatic Sulphide
# 75                        Laterite
# 107              Magmatic Sulphide
# 143              Magmatic Sulphide
# 266                       Laterite
# 301                       Laterite
# 341              Magmatic Sulphide
# 346   Laterite & Magmatic Sulphide
# 394              Magmatic Sulphide
# 455                       Laterite
# 914              Magmatic Sulphide
# 1030             Magmatic Sulphide
# 1157             Magmatic Sulphide
#
#                                  geologic_ore_body_type  \
# 67                   Layered Mafic-Ultramafic Intrusion
# 68    Laterite (Ni-Co - Limonite), Laterite (Ni-Sapr...
# 70                          Laterite (Ni-Co - Limonite)
# 73                                  Komatiitic Magmatic
# 74                                  Komatiitic Magmatic
# 75                                   Laterite (Generic)
# 107
# 143
# 266                                  Laterite (Generic)
# 301                                  Laterite (Generic)
# 341                                 Komatiitic Magmatic
# 346                                 Komatiitic Magmatic
# 394
# 455
# 914
# 1030                                Komatiitic Magmatic
# 1157                                 Laterite (Generic)
#
#       production_ROM_Ni_tpa  production_PROD_Ni_tpa         production_forms  \
# 67                  6316.00                 4828.00              Concentrate
# 68                 51900.00                47400.00          Granules, Matte
# 70                 38423.00                23400.00  Carbonate, Precipitates
# 73                 38583.95                28610.00              Concentrate
# 74                 10825.44                 8000.00              Concentrate
# 75                  9529.41                 8100.00                 Cathodes
# 107                 9563.00                 6073.00
# 143                 9300.00                 2070.00
# 266                 2627.00                 2253.97
# 301                22600.00                16889.00      Carbonate, Sulfates
# 341               102459.02                75000.00       Concentrate, Matte
# 346                 1582.00                 1344.70
# 394                13281.00                 9570.00
# 455                56908.67                48600.00
# 914                     NaN                     NaN
# 1030               23430.00                17525.64
# 1157                    NaN                     NaN                    Matte
#
#                         metall_process  recovery_Ni_perc  production_capacity  \
# 67                                   F             76.40              8000.00
# 68                                RKEF             91.30             75000.00
# 70                                HPAL             60.90             55000.00
# 73                                   F             74.15             43254.16
# 74                      pyrometallurgy             73.90             12094.84
# 75                      pyrometallurgy             85.00             17000.00
# 107                                  F             63.50              9181.49
# 143                    hydrometallurgy             22.30              3129.54
# 266                               HPAL             85.80              2953.60
# 301                                 HL             85.00             22131.35
# 341   pyrometallurgy + hydrometallurgy             73.20            113389.08
# 346                             HPAL+F             85.00             45000.00
# 394                                  F             71.90             14468.45
# 455                                                85.40             63685.44
# 914                                                73.70                  NaN
# 1030                                               74.80             26496.22
# 1157                                               71.15             23878.66
#
#       start_year  mine_life  cash_cost (nickel USC/lb)  \
# 67           NaN     2033.0                     593.65
# 68           NaN        NaN                     611.82
# 70           NaN     2044.0                     641.98
# 73           NaN     2031.0                     749.81
# 74        1967.0     2040.0                     782.59
# 75        1974.0        NaN                     783.04
# 107          NaN        NaN                     769.10
# 143       2008.0        NaN                     872.54
# 266          NaN        NaN                     629.77
# 301          NaN     2030.0                     610.47
# 341          NaN     2035.0                     872.54
# 346          NaN     2049.0                     872.54
# 394       2007.0        NaN                     872.54
# 455          NaN        NaN                     872.54
# 914          NaN        NaN                     623.76
# 1030         NaN        NaN                     593.55
# 1157         NaN        NaN                     640.78
#
#       cash_cost (nickel USD/t)  cash_cost (ore USD/t)     capital_cost_type  \
# 67                    14174.38                 146.22  Initial Capital Cost
# 68                    14608.22                 250.78             Expansion
# 70                    15328.34                 215.43  Initial Capital Cost
# 73                    17902.97                  35.62
# 74                    18685.64                 151.07  Initial Capital Cost
# 75                    18696.38                    NaN  Initial Capital Cost
# 107                   18363.47                    NaN
# 143                   20833.33                    NaN
# 266                   15036.83                    NaN
# 301                   14575.96                    NaN  Initial Capital Cost
# 341                   20833.33                    NaN  Initial Capital Cost
# 346                   20833.33                    NaN  Initial Capital Cost
# 394                   20833.33                    NaN
# 455                   20833.33                    NaN
# 914                   14893.41                    NaN
# 1030                  14172.07                    NaN  Initial Capital Cost
# 1157                  15299.72                    NaN        Major Purchase
#
#       amt_capital_invested country/region_op_risk country/region_ter_risk  \
# 67            4.642625e+04                    Low                     Low
# 68                     NaN                    Low           Insignificant
# 70            4.300000e+06                    Low           Insignificant
# 73                     NaN                    Low                     Low
# 74            3.440000e+04                    Low                     Low
# 75            5.280000e+05                   High           Insignificant
# 107                    NaN
# 143                    NaN                    Low                     Low
# 266                    NaN                    Low                     Low
# 301           7.127683e+05                    Low                     Low
# 341           3.105000e+05                    Low                     Low
# 346           1.500000e+06                    Low                     Low
# 394                    NaN                    Low                     Low
# 455                    NaN                    Low           Insignificant
# 914                    NaN                 Medium                     Low
# 1030          1.045000e+05                    Low                     Low
# 1157          4.100000e+04                   High                  Medium
#
#      country/region_pol_risk country/region_sec_risk  \
# 67                       Low                     Low
# 68                    Medium                     Low
# 70                    Medium                     Low
# 73                       Low                     Low
# 74                       Low                     Low
# 75                      High                    High
# 107
# 143                      Low                     Low
# 266                      Low                     Low
# 301                      Low                     Low
# 341                      Low                     Low
# 346                      Low                     Low
# 394                      Low                     Low
# 455                   Medium                     Low
# 914                   Medium                     Low
# 1030                     Low                     Low
# 1157                  Medium                  Medium
#
#                                                  remark    current_stage
# 67    Norilsk Nickel Resource Statement 2018Panorami...  Operating-stage
# 68    only concerns high-grade oreEramet SA 2019 Reg...  Operating-stage
# 70    Eramet SA Registration Document 2019Vale AnnRp...  Operating-stage
# 73                                                       Operating-stage
# 74                                             Thompson  Operating-stage
# 75    calculated from Anglo American 2011 Annual Rep...  Operating-stage
# 107   Lundin Mining Resource Statement June2019Black...  Operating-stage
# 143   Ardea Resources AnnRpt 2019Barra Resources Ltd...  Operating-stage
# 266                              Duckworth et al., 2019  Operating-stage
# 301   Western Areas Resource Statement 2019; Western...  Operating-stage
# 341                106250000AustralianMines PR 20200403  Operating-stage
# 346                        GME Resources Ltd PR20180802  Operating-stage
# 394   Anglo American Platinum AnnRpt 2019Peters et a...  Operating-stage
# 455             https://xueqiu.com/1095954241/171270773  Operating-stage
# 914                                                         Closed-stage
# 1030                                                     Operating-stage
# 1157             Norilsk Nickel Resource Statement 2019     Closed-stage

# %%
df_t['current_stage'].value_counts()
# Out:
# halt                      158
# Operating-stage           113
# Feasibility-stage          47
# Development-stage          21
# Late-stage exploration      9
# Closed-stage                3
# Construction-stage          1
# Name: current_stage, dtype: int64

# %%
pd.Series(hist_demand2).plot()
# Out:
# <AxesSubplot:>

# %%
pd.Series(hist_price).plot()
# Out:
# <AxesSubplot:>

# %%
pd.Series(hist_supply).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## regional risk and probability of shutdown

# %%
df['country/region_ter_risk'] = df['country/region_ter_risk'].map({'Medium':2, 'High':3, 'Low':1, 'Insignificant':0}).fillna(2)
df['country/region_sec_risk'] = df['country/region_sec_risk'].map({'Medium':2, 'High':3, 'Low':1, 'Insignificant':0}).fillna(2)
df['country/region_pol_risk'] = df['country/region_pol_risk'].map({'Medium':2, 'High':3, 'Low':1, 'Insignificant':0}).fillna(2)
df['country/region_op_risk'] = df['country/region_op_risk'].map({'Medium':2, 'High':3, 'Low':1, }).fillna(2)
df['country/region_overall_risk'] = df['country/region_ter_risk'] + df['country/region_sec_risk'] + \
                                    df['country/region_pol_risk'] + df['country/region_op_risk']
df['prob_shutdown'] = np.power(df['country/region_overall_risk']/10, 6)

# %% [markdown]
# https://mrmr.cim.org/media/1128/cim-definition-standards_2014.pdf

# %%
pd.Series(demand_list, index=range(2020, 2060)).plot(label='demand')
pd.Series(production_list, index=range(2020, 2060)).plot(label='supply')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [249], in <cell line: 1>()
# ----> 1 pd.Series(demand_list, index=range(2020, 2060)).plot(label='demand')
#       2 pd.Series(production_list, index=range(2020, 2060)).plot(label='supply')
#       3 plt.legend()
#
# NameError: name 'demand_list' is not defined

# %% [markdown]
# # Visualization

# %%
import plotly.express as px
import plotly.graph_objs as go

# %%
labels = df['country_name'].value_counts().index.tolist()[:19]

# %%
data = tp[11].copy()
data = data[data['production (mt)']>0]
data = data.sort_values(by='production (mt)', ascending=False).head(70)
data['production (mt)_bin'] = pd.cut(data['production (mt)'], bins=[-np.inf, 1000, 2000, 5000, 10000, 20000, 50000, 100000, np.inf], labels=range(1, 9)).astype(float)
data = data.rename(columns={'production (mt)_bin':'productivity level'})

data.loc[:, 'country_name_new'] = data.loc[:, 'country_name']
data.loc[~df['country_name'].isin(labels), 'country_name_new'] = 'others'

data = data.sort_values(by='country_name_new', ascending=False)

token = 'pk.eyJ1IjoiemlwcGVlIiwiYSI6ImNreGluZW5iMzAwNTUyb256aGxiYzJhNm8ifQ.MbI3pSI-pcwr2QA070dtew'
fig = px.scatter_mapbox(data,
                        lon = 'longitude',
                        lat = 'latitude',
#                         color = 'country_name_new',
                        title = 'nickel mine distribution',
                        zoom = 1,
                        category_orders=dict(zip(labels+['others'], range(20))),
                        size = 'production (mt)',
                        size_max = data['production (mt)'].max()/5000,
                        width=1000,
                        height=600,
                        color_continuous_scale = px.colors.carto.Sunsetdark)
fig.update_layout(mapbox = {'accesstoken':token, 'style':"light" },
                 title = dict(x=0.5,xref='paper'),
                 margin={'l':10,"r":0,'t':50,'b':10})
